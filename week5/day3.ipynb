# %% [markdown]
# # Day 3 — Pipeline RAG: chunking, indexacao, recuperacao
#
# **Semana:** week5 | **Repo de referência:** [ed-donner/llm_engineering/week5](https://github.com/ed-donner/llm_engineering/tree/main/week5)
#
# ---
#
# ## Anotações da aula
#
# ## Meus experimentos

# %%
from dotenv import load_dotenv

load_dotenv()
