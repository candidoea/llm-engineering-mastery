# %% [markdown]
# # Day 2 — Multi-agent frameworks
#
# **Semana:** week8 | **Repo de referência:** [ed-donner/llm_engineering/week8](https://github.com/ed-donner/llm_engineering/tree/main/week8)
#
# ---
#
# ## Anotações da aula
#
# ## Meus experimentos

# %%
from dotenv import load_dotenv
load_dotenv()
