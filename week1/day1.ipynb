# %% [markdown]
# # Day 1 — Primeiro contato com LLMs locais via Ollama
#
# **Semana:** week1 | **Repo de referência:** [ed-donner/llm_engineering/week1](https://github.com/ed-donner/llm_engineering/tree/main/week1)
#
# ---
#
# ## Anotações da aula
#
# ## Meus experimentos

# %%
from dotenv import load_dotenv

load_dotenv()
