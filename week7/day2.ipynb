# %% [markdown]
# # Day 2 — SFT com trl: loop de treinamento
#
# **Semana:** week7 | **Repo de referência:** [ed-donner/llm_engineering/week7](https://github.com/ed-donner/llm_engineering/tree/main/week7)
#
# ---
#
# ## Anotações da aula
#
# ## Meus experimentos

# %%
from dotenv import load_dotenv
load_dotenv()
