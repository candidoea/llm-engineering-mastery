# %% [markdown]
# # Day 5 — Exercício: automacao com HuggingFace
#
# **Semana:** week3 | **Repo de referência:** [ed-donner/llm_engineering/week3](https://github.com/ed-donner/llm_engineering/tree/main/week3)
#
# ---
#
# ## Anotações da aula
#
# ## Meus experimentos

# %%
from dotenv import load_dotenv
load_dotenv()
