# %% [markdown]
# # Day 1 — Frameworks de avaliacao de LLMs
#
# **Semana:** week4 | **Repo de referência:** [ed-donner/llm_engineering/week4](https://github.com/ed-donner/llm_engineering/tree/main/week4)
#
# ---
#
# ## Anotações da aula
#
# ## Meus experimentos

# %%
from dotenv import load_dotenv
load_dotenv()
